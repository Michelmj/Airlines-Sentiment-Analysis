# %% [markdown]
# # Loading Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import nltk, re, string, warnings

# %% [markdown]
# Uploading the dataset and looking it the first 5 rows

# %%
sentair = pd.read_csv("C:/Users/Delmafia91/Downloads/AirlinesTweets.csv")
print(sentair.head(5))
print(sentair.describe())
print(sentair.info())
print(sentair.shape)
# Out:
#        tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0  5.700000e+17           neutral                        1.0000
# 1  5.700000e+17          positive                        0.3486
# 2  5.700000e+17           neutral                        0.6837
# 3  5.700000e+17          negative                        1.0000
# 4  5.700000e+17          negative                        1.0000
#
#   negativereason  negativereason_confidence         airline  \
# 0            NaN                        NaN  Virgin America
# 1            NaN                     0.0000  Virgin America
# 2            NaN                        NaN  Virgin America
# 3     Bad Flight                     0.7033  Virgin America
# 4     Can't Tell                     1.0000  Virgin America
#
#   airline_sentiment_gold        name negativereason_gold  retweet_count  \
# 0                    NaN     cairdin                 NaN              0
# 1                    NaN    jnardino                 NaN              0
# 2                    NaN  yvonnalynn                 NaN              0
# 3                    NaN    jnardino                 NaN              0
# 4                    NaN    jnardino                 NaN              0
#
#                                                 text tweet_coord  \
# 0                @VirginAmerica What @dhepburn said.         NaN
# 1  @VirginAmerica plus you've added commercials t...         NaN
# 2  @VirginAmerica I didn't today... Must mean I n...         NaN
# 3  @VirginAmerica it's really aggressive to blast...         NaN
# 4  @VirginAmerica and it's a really big bad thing...         NaN
#
#      tweet_created tweet_location               user_timezone
# 0  2/24/2015 11:35            NaN  Eastern Time (US & Canada)
# 1  2/24/2015 11:15            NaN  Pacific Time (US & Canada)
# 2  2/24/2015 11:15      Lets Play  Central Time (US & Canada)
# 3  2/24/2015 11:15            NaN  Pacific Time (US & Canada)
# 4  2/24/2015 11:14            NaN  Pacific Time (US & Canada)
#            tweet_id  airline_sentiment_confidence  negativereason_confidence  \
# count  1.464000e+04                  14640.000000               10522.000000
# mean   5.692605e+17                      0.900169                   0.638298
# std    8.098842e+14                      0.162830                   0.330440
# min    5.680000e+17                      0.335000                   0.000000
# 25%    5.690000e+17                      0.692300                   0.360600
# 50%    5.690000e+17                      1.000000                   0.670600
# 75%    5.700000e+17                      1.000000                   1.000000
# max    5.700000e+17                      1.000000                   1.000000
#
#        retweet_count
# count   14640.000000
# mean        0.082650
# std         0.745778
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max        44.000000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14640 entries, 0 to 14639
# Data columns (total 15 columns):
# tweet_id                        14640 non-null float64
# airline_sentiment               14640 non-null object
# airline_sentiment_confidence    14640 non-null float64
# negativereason                  9178 non-null object
# negativereason_confidence       10522 non-null float64
# airline                         14640 non-null object
# airline_sentiment_gold          40 non-null object
# name                            14640 non-null object
# negativereason_gold             32 non-null object
# retweet_count                   14640 non-null int64
# text                            14640 non-null object
# tweet_coord                     1019 non-null object
# tweet_created                   14640 non-null object
# tweet_location                  9907 non-null object
# user_timezone                   9820 non-null object
# dtypes: float64(3), int64(1), object(11)
# memory usage: 1.7+ MB
# None
# (14640, 15)

# %% [markdown]
# # Data Inspection
# Checking the dataset

# %%
print('Size of Sentair is:', sentair.shape)
print('Columns of Sentair are:', sentair.columns)
# Out:
# Size of Sentair is: (14640, 15)
# Columns of Sentair are: Index(['tweet_id', 'airline_sentiment', 'airline_sentiment_confidence',
#        'negativereason', 'negativereason_confidence', 'airline',
#        'airline_sentiment_gold', 'name', 'negativereason_gold',
#        'retweet_count', 'text', 'tweet_coord', 'tweet_created',
#        'tweet_location', 'user_timezone'],
#       dtype='object')

# %% [markdown]
# As a custom, we need to check for any null value within any data.

# %%
print('The number of null value in Sentair:', sentair.isna().sum())
# Out:
# The number of null value in Sentair: tweet_id                            0
# airline_sentiment                   0
# airline_sentiment_confidence        0
# negativereason                   5462
# negativereason_confidence        4118
# airline                             0
# airline_sentiment_gold          14600
# name                                0
# negativereason_gold             14608
# retweet_count                       0
# text                                0
# tweet_coord                     13621
# tweet_created                       0
# tweet_location                   4733
# user_timezone                    4820
# dtype: int64

# %% [markdown]
# What is the percentage of null value in the Sentair dataframe

# %%
print('Percentage of null or na values in Sentair')
((sentair.isnull() | sentair.isna()).sum()*100 / sentair.index.size).round(2)
# Out:
# Percentage of null or na values in Sentair
# tweet_id                         0.00
# airline_sentiment                0.00
# airline_sentiment_confidence     0.00
# negativereason                  37.31
# negativereason_confidence       28.13
# airline                          0.00
# airline_sentiment_gold          99.73
# name                             0.00
# negativereason_gold             99.78
# retweet_count                    0.00
# text                             0.00
# tweet_coord                     93.04
# tweet_created                    0.00
# tweet_location                  32.33
# user_timezone                   32.92
# dtype: float64

# %% [markdown]
# From this percentage, we can see that "Airline sentiment gold, negative reason gold, and tweet coord" have more than 90% missing data. Since we want to make life easier, we are going to remove these columns from the Sentair dataset.

# %%
sentair = sentair.drop(columns = ['tweet_coord', 'airline_sentiment_gold', 'negativereason_gold'])

# %%
print(sentair.head(5))
print(sentair.info())
print(sentair.shape)
# Out:
#        tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0  5.700000e+17           neutral                        1.0000
# 1  5.700000e+17          positive                        0.3486
# 2  5.700000e+17           neutral                        0.6837
# 3  5.700000e+17          negative                        1.0000
# 4  5.700000e+17          negative                        1.0000
#
#   negativereason  negativereason_confidence         airline        name  \
# 0            NaN                        NaN  Virgin America     cairdin
# 1            NaN                     0.0000  Virgin America    jnardino
# 2            NaN                        NaN  Virgin America  yvonnalynn
# 3     Bad Flight                     0.7033  Virgin America    jnardino
# 4     Can't Tell                     1.0000  Virgin America    jnardino
#
#    retweet_count                                               text  \
# 0              0                @VirginAmerica What @dhepburn said.
# 1              0  @VirginAmerica plus you've added commercials t...
# 2              0  @VirginAmerica I didn't today... Must mean I n...
# 3              0  @VirginAmerica it's really aggressive to blast...
# 4              0  @VirginAmerica and it's a really big bad thing...
#
#      tweet_created tweet_location               user_timezone
# 0  2/24/2015 11:35            NaN  Eastern Time (US & Canada)
# 1  2/24/2015 11:15            NaN  Pacific Time (US & Canada)
# 2  2/24/2015 11:15      Lets Play  Central Time (US & Canada)
# 3  2/24/2015 11:15            NaN  Pacific Time (US & Canada)
# 4  2/24/2015 11:14            NaN  Pacific Time (US & Canada)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14640 entries, 0 to 14639
# Data columns (total 12 columns):
# tweet_id                        14640 non-null float64
# airline_sentiment               14640 non-null object
# airline_sentiment_confidence    14640 non-null float64
# negativereason                  9178 non-null object
# negativereason_confidence       10522 non-null float64
# airline                         14640 non-null object
# name                            14640 non-null object
# retweet_count                   14640 non-null int64
# text                            14640 non-null object
# tweet_created                   14640 non-null object
# tweet_location                  9907 non-null object
# user_timezone                   9820 non-null object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 1.3+ MB
# None
# (14640, 12)

# %% [markdown]
# Let us do a summary of the Sentair dataset

# %%
print(sentair.sum())
# Out:
# tweet_id                                                              8.33397e+21
# airline_sentiment               neutralpositiveneutralnegativenegativenegative...
# airline_sentiment_confidence                                              13178.5
# negativereason_confidence                                                 6716.17
# airline                         Virgin AmericaVirgin AmericaVirgin AmericaVirg...
# name                            cairdinjnardinoyvonnalynnjnardinojnardinojnard...
# retweet_count                                                                1210
# text                            @VirginAmerica What @dhepburn said.@VirginAmer...
# tweet_created                   2/24/2015 11:352/24/2015 11:152/24/2015 11:152...
# dtype: object

# %%
print(sentair.mean())
# Out:
# tweet_id                        5.692605e+17
# airline_sentiment_confidence    9.001689e-01
# negativereason_confidence       6.382983e-01
# retweet_count                   8.265027e-02
# dtype: float64

# %%
print(sentair.std())
# Out:
# tweet_id                        8.098842e+14
# airline_sentiment_confidence    1.628300e-01
# negativereason_confidence       3.304398e-01
# retweet_count                   7.457782e-01
# dtype: float64

# %% [markdown]
# Now that we have an idea of what is going on, let us look at each sentiment for each airline and see what the main words are

# %% [markdown]
# We can do a sum of the number of tweets and add some plots for each airline as it relates to the sentiments; positive, negative, and neutral. Plotting always helps

# %%
sentair.groupby('airline').head()
# Out:
#            tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0      5.700000e+17           neutral                        1.0000
# 1      5.700000e+17          positive                        0.3486
# 2      5.700000e+17           neutral                        0.6837
# 3      5.700000e+17          negative                        1.0000
# 4      5.700000e+17          negative                        1.0000
# 504    5.700000e+17          positive                        1.0000
# 505    5.700000e+17          positive                        1.0000
# 506    5.700000e+17          negative                        1.0000
# 507    5.700000e+17          negative                        1.0000
# 508    5.700000e+17          positive                        0.3441
# 4326   5.700000e+17          negative                        1.0000
# 4327   5.700000e+17          negative                        0.6361
# 4328   5.700000e+17          negative                        1.0000
# 4329   5.700000e+17           neutral                        0.6443
# 4330   5.700000e+17          negative                        1.0000
# 6746   5.700000e+17          positive                        0.6469
# 6747   5.700000e+17           neutral                        0.6869
# 6748   5.700000e+17           neutral                        1.0000
# 6749   5.700000e+17          negative                        1.0000
# 6750   5.700000e+17          negative                        1.0000
# 8966   5.700000e+17          negative                        0.6292
# 8967   5.700000e+17          negative                        1.0000
# 8968   5.700000e+17           neutral                        1.0000
# 8969   5.700000e+17           neutral                        1.0000
# 8970   5.700000e+17          negative                        1.0000
# 11879  5.700000e+17          negative                        1.0000
# 11880  5.700000e+17           neutral                        0.6667
# 11881  5.700000e+17          negative                        0.6316
# 11882  5.700000e+17          negative                        0.6846
# 11883  5.700000e+17          negative                        0.6547
#
#                     negativereason  negativereason_confidence         airline  \
# 0                              NaN                        NaN  Virgin America
# 1                              NaN                     0.0000  Virgin America
# 2                              NaN                        NaN  Virgin America
# 3                       Bad Flight                     0.7033  Virgin America
# 4                       Can't Tell                     1.0000  Virgin America
# 504                            NaN                        NaN          United
# 505                            NaN                        NaN          United
# 506               Cancelled Flight                     0.7030          United
# 507                    Late Flight                     1.0000          United
# 508                            NaN                     0.0000          United
# 4326                     longlines                     0.6624       Southwest
# 4327              Cancelled Flight                     0.6361       Southwest
# 4328        Customer Service Issue                     1.0000       Southwest
# 4329                           NaN                        NaN       Southwest
# 4330        Customer Service Issue                     1.0000       Southwest
# 6746                           NaN                        NaN           Delta
# 6747                           NaN                        NaN           Delta
# 6748                           NaN                        NaN           Delta
# 6749   Flight Attendant Complaints                     0.6522           Delta
# 6750                    Bad Flight                     1.0000           Delta
# 8966       Flight Booking Problems                     0.3146      US Airways
# 8967        Customer Service Issue                     1.0000      US Airways
# 8968                           NaN                        NaN      US Airways
# 8969                           NaN                        NaN      US Airways
# 8970        Customer Service Issue                     0.6452      US Airways
# 11879       Customer Service Issue                     1.0000        American
# 11880                          NaN                        NaN        American
# 11881                   Bad Flight                     0.3164        American
# 11882      Flight Booking Problems                     0.6846        American
# 11883                  Late Flight                     0.3331        American
#
#                   name  retweet_count  \
# 0              cairdin              0
# 1             jnardino              0
# 2           yvonnalynn              0
# 3             jnardino              0
# 4             jnardino              0
# 504         rdowning76              0
# 505      CoreyAStewart              0
# 506     CoralReefer420              0
# 507         lsalazarll              0
# 508             rombaa              0
# 4326       thisradlove              0
# 4327         tomcblock              0
# 4328    cindyjwhitaker              0
# 4329      liveseasoned              0
# 4330    cindyjwhitaker              0
# 6746            jaxbra              0
# 6747   Oneladyyouadore              0
# 6748   Oneladyyouadore              0
# 6749   Oneladyyouadore              0
# 6750   Oneladyyouadore              0
# 8966         jhazelnut              0
# 8967          GAKotsch              0
# 8968     DebbiMcGinnis              0
# 8969   AshleyKAtherton              0
# 8970     retardedlarry              0
# 11879       SweeLoTmac              0
# 11880  LancasterPattie              0
# 11881        ELLLORRAC              0
# 11882       SweeLoTmac              0
# 11883      LauraMolito              0
#
#                                                     text    tweet_created  \
# 0                    @VirginAmerica What @dhepburn said.  2/24/2015 11:35
# 1      @VirginAmerica plus you've added commercials t...  2/24/2015 11:15
# 2      @VirginAmerica I didn't today... Must mean I n...  2/24/2015 11:15
# 3      @VirginAmerica it's really aggressive to blast...  2/24/2015 11:15
# 4      @VirginAmerica and it's a really big bad thing...  2/24/2015 11:14
# 504                                       @united thanks  2/24/2015 11:42
# 505    @united Thanks for taking care of that MR!! Ha...  2/24/2015 11:42
# 506    @united still no refund or word via DM. Please...  2/24/2015 11:39
# 507    @united Delayed due to lack of crew and now de...  2/24/2015 11:39
# 508    @united thanks -- we filled it out. How's our ...  2/24/2015 11:38
# 4326     @SouthwestAir still waiting. Just hit one hour.  2/24/2015 11:47
# 4327   @SouthwestAir although I'm not happy you Cance...  2/24/2015 11:47
# 4328   @SouthwestAir Hello - been on hold for extreme...  2/24/2015 11:41
# 4329   @SouthwestAir I'm teaching new #travelers how ...  2/24/2015 11:35
# 4330   @SouthwestAir Very frustrated for the loooooon...  2/24/2015 11:33
# 6746   @JetBlue Yesterday on my way from EWR to FLL j...  2/24/2015 11:48
# 6747   @JetBlue I hope so because I fly very often an...  2/24/2015 11:48
# 6748                @JetBlue flight 1041 to Savannah, GA  2/24/2015 11:45
# 6749   @JetBlue They weren't on any flight, they just...  2/24/2015 11:42
# 6750   @JetBlue everyone is here but our pilots are n...  2/24/2015 11:32
# 8966   @USAirways  is there a better time to call? My...  2/24/2015 11:53
# 8967   @USAirways and when will one of these agents b...  2/24/2015 11:51
# 8968   @USAirways is a DM possible if you aren't foll...  2/24/2015 11:48
# 8969   @USAirways Fortunately you have staff like Lyn...  2/24/2015 11:47
# 8970   @USAirways just hung up on me again.  Another ...  2/24/2015 11:46
# 11879  @AmericanAir why would I even consider continu...  2/24/2015 11:44
# 11880  @AmericanAir we've already made other arrangem...  2/24/2015 11:43
# 11881  @AmericanAir thanks for getting back to me. Bu...  2/24/2015 11:43
# 11882  @AmericanAir why would I pay $200 to reactivat...  2/24/2015 11:43
# 11883  @AmericanAir stranded for 24 hours in MIA, Pat...  2/24/2015 11:41
#
#                  tweet_location                user_timezone
# 0                           NaN   Eastern Time (US & Canada)
# 1                           NaN   Pacific Time (US & Canada)
# 2                     Lets Play   Central Time (US & Canada)
# 3                           NaN   Pacific Time (US & Canada)
# 4                           NaN   Pacific Time (US & Canada)
# 504                         usa                          NaN
# 505                Richmond, VA   Eastern Time (US & Canada)
# 506       Bay Area, California                        Alaska
# 507                         NaN  Mountain Time (US & Canada)
# 508                         NaN                          NaN
# 4326    Today I'm in: Maryland        Atlantic Time (Canada)
# 4327   ÜT: 38.965477,-77.428287   Eastern Time (US & Canada)
# 4328                        NaN   Central Time (US & Canada)
# 4329                        NaN                          NaN
# 4330                        NaN   Central Time (US & Canada)
# 6746         east brunswick, nj       Atlantic Time (Canada)
# 6747                    Georgia                        Quito
# 6748                    Georgia                        Quito
# 6749                    Georgia                        Quito
# 6750                    Georgia                        Quito
# 8966                        NaN                          NaN
# 8967                        NaN       Atlantic Time (Canada)
# 8968                  Missourah                       Hawaii
# 8969                        NaN   Central Time (US & Canada)
# 8970                        NaN                          NaN
# 11879                       NaN                        Quito
# 11880                       NaN                          NaN
# 11881                       NaN   Central Time (US & Canada)
# 11882                       NaN                        Quito
# 11883              New York, NY       Atlantic Time (Canada)

# %%
print('Total number of sentiments for tweets for the airline \n', sentair.groupby('airline')['airline_sentiment'].count().sort_values(ascending = False))
airline = ['US Airways', 'United', 'American', 'Southwest', 'Delta', 'Virgin America']
plt.figure(1, figsize = (60, 30))
for m in airline: 
    indices = airline.index(m)
    plt.subplot(2, 3, indices + 1)
    sentair0 = sentair[sentair['airline'] == m]
    count = sentair0['airline_sentiment'].value_counts()
    Index = [1,2,3]
    plt.bar(Index, count, color = ['yellow', 'red', 'blue'])
    plt.xticks(Index, ['negative', 'neutral', 'positive'])
    plt.xlabel('Sentiments', fontsize = 55)
    plt.ylabel('Count', fontsize = 55)
    plt.title('Count of Different Sentiments by ' + m, fontsize = 53)
# Out:
# Total number of sentiments for tweets for the airline
#  airline
# United            3822
# US Airways        2913
# American          2759
# Southwest         2420
# Delta             2222
# Virgin America     504
# Name: airline_sentiment, dtype: int64

# %% [markdown]
# It looks as if Virgin America is doing a lot better at keeping customers happy. It is interesting how most people have negative sentiments about these six airline industries. Nevertheless, the top two airlines are Virgin America and Delta. Southwest should have been at the top of the latter since it gives two luggages and two carry-ons and personal items for free. Yet people still have bad sentiments about Southwest. Southwest is my favorite airline industry, by the way!

# %% [markdown]
# What are the most used words in Positive and Negative tweets?
# There is something called "WordCloud" in python that can help us
# find all the words we need. Since Negative words are the most
# frequent ones, we are going to take a look at them first. What we are going to look for as the most frequent words, are going to be in bigger letters; and as we see words with smaller letters, we will understand they are less frequently used

# %%
from wordcloud import WordCloud, STOPWORDS

# %% [markdown]
# Wordcloud is used for word visualization techniques. We will take a look at the negative words first

# %%
newsentair = sentair[sentair['airline_sentiment'] == 'negative']
words = ' '.join(newsentair['text'])
worD = " ".join([word for word in words.split()
                     if 'http' not in word and 
                      not word.startswith('@')
                     and word != 'RT'])
wordcloud = WordCloud(stopwords = STOPWORDS, 
                     background_color = 'yellow',
                     width = 3500, 
                     height = 3000,
                     ).generate(worD)
plt.figure(1, figsize = (20, 18))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %% [markdown]
# Now let us look at the positive sentiments given

# %%
newsentair = sentair[sentair['airline_sentiment'] == 'positive']
words = ' '.join(newsentair['text'])
Word = " ".join([word for word in words.split()
                   if 'http' not in word and not 
                    word.startswith('@') and word != 'RT'])
wordcloud = WordCloud(stopwords = STOPWORDS, 
                     background_color = 'blue',
                     width = 3500, 
                    height = 3000).generate(Word)
plt.figure(1, figsize = (20, 18))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
newsentair = sentair[sentair['airline_sentiment'] == 'neutral']
words = ' '.join(newsentair['text'])
word = " ".join([word for word in words.split()
                   if 'http' not in word and not 
                   word.startswith ('@') and word != 'RT'])
wordcloud = WordCloud(stopwords = STOPWORDS, 
                     background_color = 'red', 
                     width = 3500,
                     height = 3000).generate(word)
plt.figure(1, figsize = (20, 18))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %% [markdown]
# We can see there is somewhat a difference between the positive, negative, and neutral sentiment portayed here. But, some words may appear in both neutral and negative, or neutral and positive because each person views certain things differently. Now it would be good to find out how many times some of these words are used.
#
# We are going to see the highest frequency words in positive, negative and neutral sentiments

# %%
def freq(str):
    str = str.split()
    str1 = []
    
    for i in str:
        if i not in str1:
            str1.append(i)
            
    for i in range(0, len(str1)):
        if(str.count(str1[i]) > 50):
            print('Frequence of', str1[i], 'is:', 
                  str.count(str1[i]))
print(freq(word))
# Out:
# Frequence of I is: 1105
# Frequence of need is: 135
# Frequence of to is: 1646
# Frequence of a is: 771
# Frequence of for is: 598
# Frequence of you is: 631
# Frequence of know is: 96
# Frequence of that is: 196
# Frequence of is is: 401
# Frequence of the is: 928
# Frequence of of is: 343
# Frequence of will is: 173
# Frequence of be is: 225
# Frequence of do is: 205
# Frequence of - is: 171
# Frequence of on is: 631
# Frequence of at is: 206
# Frequence of are is: 168
# Frequence of with is: 236
# Frequence of from is: 322
# Frequence of when is: 110
# Frequence of can is: 313
# Frequence of my is: 490
# Frequence of flight is: 419
# Frequence of help is: 110
# Frequence of me is: 259
# Frequence of have is: 280
        if i not in str1:
            str1.append(i)
            
    for i in range(0, len(str1)):
        if(str.count(str1[i]) > 50):
            print('Frequence of', str1[i], 'is:', 
                  str.count(str1[i]))
print(freq(Word))
# Out:
# Frequence of to is: 923
# Frequence of the is: 924
# Frequence of time is: 59
# Frequence of I is: 574
# Frequence of fly is: 54
# Frequence of this is: 143
# Frequence of :) is: 96
# Frequence of it is: 166
# Frequence of was is: 226
# Frequence of and is: 416
# Frequence of an is: 74
# Frequence of good is: 75
# Frequence of so is: 163
# Frequence of much is: 54
# Frequence of is is: 219
# Frequence of a is: 501
# Frequence of great is: 144
# Frequence of my is: 320
# Frequence of &amp; is: 77
# Frequence of on is: 327
# Frequence of I'm is: 67
# Frequence of flying is: 59
# Frequence of your is: 212
# Frequence of all is: 92
# Frequence of from is: 124
# Frequence of Thanks! is: 69
# Frequence of for is: 658
# Frequence of flight is: 263
# Frequence of but is: 91
# Frequence of you is: 509
# Frequence of would is: 56
# Frequence of be is: 135
# Frequence of with is: 195
# Frequence of you. is: 77
# Frequence of love is: 85
# Frequence of You is: 62
# Frequence of are is: 120
# Frequence of of is: 236
# Frequence of that is: 102
# Frequence of in is: 309
# Frequence of just is: 129
# Frequence of very is: 55
# Frequence of not is: 57
# Frequence of been is: 52
# Frequence of like is: 57
# Frequence of we is: 75
# Frequence of can is: 54
# Frequence of crew is: 51
# Frequence of - is: 87
# Frequence of customer is: 101
# Frequence of back is: 54
# Frequence of us is: 62
# Frequence of out is: 71
# Frequence of best is: 63
# Frequence of have is: 124
# Frequence of Thank is: 231
# Frequence of at is: 178
# Frequence of thanks is: 218
# Frequence of get is: 111
# Frequence of me is: 196
# Frequence of service is: 100
# Frequence of you! is: 129
# Frequence of Thanks is: 177
# Frequence of as is: 57
# Frequence of thank is: 204
# Frequence of will is: 85
# Frequence of our is: 64
# Frequence of up is: 66
# Frequence of guys is: 76
# Frequence of got is: 85
# Frequence of made is: 55
# None

# %% [markdown]
# Now that we know about the sentiments for each airline, why these sentiments are expressed we do not know. Let us try to find out why.

# %%
sentair['negativereason'].nunique()

negreason = dict(sentair['negativereason'].value_counts(sort 
                                                        = False))

def negreason(Airline):
    if Airline == 'All':
        a = sentair
    else:
        a = sentair[sentair['airline'] == Airline]
    count = dict(a['negativereason'].value_counts())
    Reason = list(sentair['negativereason'].unique())
    Reason = [x for x in Reason if str(x) != 'nan']
    Framereason = pd.DataFrame({'Reasons' : Reason})
    Framereason['count'] = Framereason['Reasons'].apply(
        lambda x: count[x])
    return Framereason

# %%
def reasonplot(Airline):
    
    a = negreason(Airline)
    count = a['count']
    Index = range(1, (len(a) + 1))
    plt.bar(Index, count, color = ['red', 'yellow', 'blue', 
                'green', 'black', 'brown', 'gray', 'cyan', 
                'purple', 'orange'])
    plt.xticks(Index, a['Reasons'], rotation = 90)
    plt.ylabel('Count')
    plt.xlabel('Reason', fontsize = 30)
    plt.title('Count of Negative Reasons for ' +Airline)
    
reasonplot('All')
plt.figure(2, figsize = (13, 13))

for i in airline:
    indices = airline.index(i)
    plt.subplot(2, 3, indices + 1)
    plt.subplots_adjust(hspace = 0.9)
    reasonplot(i)
